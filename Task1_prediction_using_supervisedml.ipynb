# %% [markdown]
# **THE SPARKS FOUNDATION**
#
# Data Science & Business Analytics internship - AUGUST 2021
#
# Task 1 : PREDICTION USUING SUPERVISED ML
#
# Author : **SUHAS.KM**

# %% [markdown]
# ### Importing all the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Importing Data

# %%
url = "http://bit.ly/w-data"
stud_data = pd.read_csv(url)
print("Data imported successfully")
stud_data.head(10)
# Out:
# Data imported successfully
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30
# 5    1.5      20
# 6    9.2      88
# 7    5.5      60
# 8    8.3      81
# 9    2.7      25

# %%
#Checking for a null value in the dataset
stud_data.isnull == True
# Out:
# False

# %% [markdown]
# ### Since there is no null value we can proceed with the visualization of the dataset

# %%
#Plotting the distribution of scores
stud_data.plot(x='Hours',y='Scores',style='o')
plt.title('Hours vs percentage')
plt.xlabel('Hours studied')
plt.ylabel('Percentage score')
plt.show()

# %% [markdown]
# From the above plot we can devise that there is a positive linear relation between the number of hours studied and percentage of score.
#
# The next step is to divide the data into "attributes" (inputs) a "labels" (outputs).

# %%
X = stud_data.iloc[:, :-1].values  
y = stud_data.iloc[:, 1].values

# %% [markdown]
# Now we split the data into training and test sets by making use Sckit-Learn's built-in tarin_test_split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, 
                            test_size=0.2, random_state=0)

# %% [markdown]
# ## **Training the Algorithm**

# %%
from sklearn.linear_model import LinearRegression  
regressor = LinearRegression()  
regressor.fit(X_train, y_train) 

print("*******Training complete*******")
# Out:
# *******Training complete*******

# %%
#Plotting the regression line 

line = regressor.coef_*X+regressor.intercept_

# Plotting for the test data
plt.scatter(X, y)
plt.title('Regression plot of Hours vs Score')
plt.plot(X, line);
plt.show()

# %% [markdown]
# Plotting of the regression has shown that as the study Hour increases the Score increases proportionally

# %% [markdown]
# ## MAKING PREDICTIONS

# %%
#Using test data for making for predicting the marks

print(X_test) 
y_pred = regressor.predict(X_test)
# Out:
# [[1.5]
#  [3.2]
#  [7.4]
#  [2.5]
#  [5.9]]

# %%
#Compairing the Actual vs Predicted data

df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})  
df
# Out:
#    Actual  Predicted
# 0      20  16.884145
# 1      27  33.732261
# 2      69  75.357018
# 3      30  26.794801
# 4      62  60.491033

# %%
#Plotting the graph to get the clear picture of the dofference between Actual and Predicted value

df.plot(kind='bar',figsize=(5,5))
plt.grid(which='major', linewidth='0.5')
plt.grid(which='minor', linewidth='0.5')
plt.show()

# %%
# Testing the data with our own model

hours = 9.25
test = np.array([hours])
test = test.reshape(-1,1)
own_pred = regressor.predict(test)
print("No of Hours = {}".format(hours))
print("Predicted Score = {}".format(own_pred[0]))
# Out:
# No of Hours = 9.25
# Predicted Score = 93.69173248737539

# %% [markdown]
# ### EVALUATING THE MODEL

# %%
from sklearn import metrics  
print('Mean Absolute Error:', 
      metrics.mean_absolute_error(y_test, y_pred))
# Out:
# Mean Absolute Error: 4.183859899002982

# %% [markdown]
# ## **CONCLUSION: Prediction using "Supervised Machine Learning" task was carried out successfull**
